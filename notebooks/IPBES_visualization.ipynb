# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from code_utils.utils import aplatir

# %% [markdown]
# Visualization of the contribution of each countries in ipbes references

# %%
df_ipbes=pd.read_json(module_path+'\\IPCC_bibliography\\AR6\\structured_data\\data_ipbes_visualization.json')

# %%
color_dict = {
'FR': '#BE2125'
}

# %%
data_counts = pd.Series(aplatir(list(df_ipbes['countries']))).value_counts().drop('None')

# %%
plt.figure(figsize=(24, 10))
ax = data_counts[:20].plot(kind='bar', color=[color_dict.get(u, 'grey') for u in data_counts[:20].index], width=0.8)

for i, v in enumerate(data_counts[:20]):
    ax.text(i, v + 0.1, f'{v}', ha='center', va='bottom', color='black', size=20)
    
plt.suptitle(f"Nombre de references françaises dans l'IPBES", size=25)
plt.title('Source : OpenAlex\nTraitement : Science et Ingénierie des Données, SIES', size=10, loc='right')

ax.set_xticklabels(data_counts.index[:20], rotation='vertical', fontsize=15)
plt.show()

# %%
nb_references = len(df_ipbes.doi.dropna().drop_duplicates())
pourcent_data = (data_counts / nb_references) * 100

plt.figure(figsize=(24, 10))
ax = pourcent_data[:20].plot(kind='bar', color=[color_dict.get(u, 'grey') for u in pourcent_data[:20].index], width=0.8)

for i, v in enumerate(pourcent_data[:20]):
    ax.text(i, v + 0.1, f'{v:.2f}%', ha='center', va='bottom', color='black', fontsize=18)

plt.suptitle(f"Percentage of IPBES references in which France participated", size=25)
plt.title('Source : OpenAlex\nTraitement : Science et Ingénierie des Données, SIES', size=10, loc='right')

ax.set_xticklabels(pourcent_data.index[:20], rotation='vertical', fontsize=16)
ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)
plt.show()
# Out:
# C:\Users\haallat\AppData\Local\Temp\ipykernel_10312\714987268.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)

# %% [markdown]
# Visualization of the contribution of each countries in ipbes references - chap1

# %%
pd.Series(aplatir(list(df_ipbes_chap['countries']))).value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_ipbes_chap=df_ipbes[df_ipbes.chap=='chap_1']
data_counts = pd.Series(aplatir(list(df_ipbes_chap['countries']))).value_counts().drop(['None'])

nb_references = len(df_ipbes_chap.doi.dropna().drop_duplicates())
pourcent_data = (data_counts / nb_references) * 100

plt.figure(figsize=(24, 10))
ax = pourcent_data[:20].plot(kind='bar', color=[color_dict.get(u, 'grey') for u in pourcent_data[:20].index], width=0.8)

for i, v in enumerate(pourcent_data[:20]):
    ax.text(i, v + 0.1, f'{v:.2f}%', ha='center', va='bottom', color='black', fontsize=18)

plt.suptitle(f"Percentage of IPBES references (Chapter 1) in which France participated", size=25)
plt.title('Source : OpenAlex\nTraitement : Science et Ingénierie des Données, SIES', size=10, loc='right')

ax.set_xticklabels(pourcent_data.index[:20], rotation='vertical', fontsize=16)
ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)
plt.show()
# Out:
# C:\Users\haallat\AppData\Local\Temp\ipykernel_10312\3780843255.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)

# %% [markdown]
# Visualization of the contribution of each countries in ipbes references - chap2

# %%
df_ipbes_chap=df_ipbes[(df_ipbes.chap=='chap_2.1')|(df_ipbes.chap=='chap_2.2')|(df_ipbes.chap=='chap_2.3')]
data_counts = pd.Series(aplatir(list(df_ipbes_chap['countries']))).value_counts().drop('None')

nb_references = len(df_ipbes_chap.doi.dropna().drop_duplicates())
pourcent_data = (data_counts / nb_references) * 100

plt.figure(figsize=(24, 10))
ax = pourcent_data[:20].plot(kind='bar', color=[color_dict.get(u, 'grey') for u in pourcent_data[:20].index], width=0.8)

for i, v in enumerate(pourcent_data[:20]):
    ax.text(i, v + 0.1, f'{v:.2f}%', ha='center', va='bottom', color='black', fontsize=18)

plt.suptitle(f"Percentage of IPBES references (Chapter 2) in which France participated", size=25)
plt.title('Source : OpenAlex\nTraitement : Science et Ingénierie des Données, SIES', size=10, loc='right')

ax.set_xticklabels(pourcent_data.index[:20], rotation='vertical', fontsize=16)
ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)
plt.show()
# Out:
# C:\Users\haallat\AppData\Local\Temp\ipykernel_10312\3107563817.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)

# %% [markdown]
# Visualization of the contribution of each countries in ipbes references - chap3

# %%
df_ipbes_chap=df_ipbes[df_ipbes.chap=='chap_3']
data_counts = pd.Series(aplatir(list(df_ipbes_chap['countries']))).value_counts().drop('None')

nb_references = len(df_ipbes_chap.doi.dropna().drop_duplicates())
pourcent_data = (data_counts / nb_references) * 100

plt.figure(figsize=(24, 10))
ax = pourcent_data[:20].plot(kind='bar', color=[color_dict.get(u, 'grey') for u in pourcent_data[:20].index], width=0.8)

for i, v in enumerate(pourcent_data[:20]):
    ax.text(i, v + 0.1, f'{v:.2f}%', ha='center', va='bottom', color='black', fontsize=18)

plt.suptitle(f"Percentage of IPBES references (Chapter 3) in which France participated", size=25)
plt.title('Source : OpenAlex\nTraitement : Science et Ingénierie des Données, SIES', size=10, loc='right')

ax.set_xticklabels(pourcent_data.index[:20], rotation='vertical', fontsize=16)
ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)
plt.show()
# Out:
# C:\Users\haallat\AppData\Local\Temp\ipykernel_10312\2211863766.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f'{tick:.1f}%' for tick in ax.get_yticks()], fontsize=15)
