# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import neattext.functions as nfx
import requests
import time
from tqdm import tqdm

current_directory = os.getcwd()
root_directory = os.path.abspath(os.path.join(current_directory, '..', '..')) 
if root_directory not in sys.path:
   sys.path.append(root_directory)

import logging
logging.basicConfig(level=logging.CRITICAL)

# %%
climat_topics_str=['SUSTAINABILITY', 'DURABILITY', 'RESILIENCE', 'HABITABILITY']
climat_topics_str2=['"'+str(x).lower()+'"' for x in climat_topics_str ]

# %%
climat_topics_OR_str2=(' OR ').join(climat_topics_str2)

# %%
climat_topics_OR_str2
# Out:
# '"sustainability" OR "durability" OR "resilience" OR "habitability"'

# %%
climat_keywords_str=['"'+str(x).capitalize()+'"' for x in climat_topics_str ]

# %%
climat_keywords_str2=(' OR ').join(climat_keywords_str)
climat_keywords_str2
# Out:
# '"Sustainability" OR "Durability" OR "Resilience" OR "Habitability"'

# %%
url=f"https://api.openalex.org/works?filter=has_doi:true,publication_year:{2022},keyword.search:({climat_keywords_str2}),title_and_abstract.search:({climat_topics_OR_str2})&group-by=institutions.country_code"
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'meta': {'count': 13405,
#   'db_response_time_ms': 254,
#   'page': 1,
#   'per_page': 200,
#   'groups_count': 166},
#  'group_by': [{'key': 'https://openalex.org/countries/US',
#    'key_display_name': 'United States of America',
#    'count': 2223},
#   {'key': 'https://openalex.org/countries/CN',
#    'key_display_name': 'China',
#    'count': 1212},
#   {'key': 'https://openalex.org/countries/GB',
#    'key_display_name': 'United Kingdom of Great Britain and Northern Ireland',
#    'count': 975},
#   {'key': 'https://openalex.org/countries/ID',
#    'key_display_name': 'Indonesia',
#    'count': 594},
#   {'key': 'https://openalex.org/countries/IT',
#    'key_display_name': 'Italy',
#    'count': 520},
#   {'key': 'https://openalex.org/countries/DE',
#    'key_display_name': 'Germany',
#    'count': 497},
#   {'key': 'https://openalex.org/countries/AU',
#    'key_display_name': 'Australia',
#    'count': 463},
#   {'key': 'https://openalex.org/countries/IN',
#    'key_display_name': 'India',
#    'count': 445},
#   {'key': 'https://openalex.org/countries/CA',
#    'key_display_name': 'Canada',
#    'count': 407},
#   {'key': 'https://openalex.org/countries/NL',
#    'key_display_name': 'Netherlands',
#    'count': 310},
#   {'key': 'https://openalex.org/countries/IR',
#    'key_display_name': 'Iran, Islamic Republic of',
#    'count': 307},
#   {'key': 'https://openalex.org/countries/FR',
#    'key_display_name': 'France',
#    'count': 291},
#   {'key': 'https://openalex.org/countries/ES',
#    'key_display_name': 'Spain',
#    'count': 270},
#   {'key': 'https://openalex.org/countries/JP',
#    'key_display_name': 'Japan',
#    'count': 247},
#   {'key': 'https://openalex.org/countries/BR',
#    'key_display_name': 'Brazil',
#    'count': 200},
#   {'key': 'https://openalex.org/countries/MY',
#    'key_display_name': 'Malaysia',
#    'count': 167},
#   {'key': 'https://openalex.org/countries/SE',
#    'key_display_name': 'Sweden',
#    'count': 164},
#   {'key': 'https://openalex.org/countries/ZA',
#    'key_display_name': 'South Africa',
#    'count': 164},
#   {'key': 'https://openalex.org/countries/TR',
#    'key_display_name': 'Turkey',
#    'count': 148},
#   {'key': 'https://openalex.org/countries/PT',
#    'key_display_name': 'Portugal',
#    'count': 134},
#   {'key': 'https://openalex.org/countries/KR',
#    'key_display_name': 'Korea, Republic of',
#    'count': 132},
#   {'key': 'https://openalex.org/countries/CH',
#    'key_display_name': 'Switzerland',
#    'count': 131},
#   {'key': 'https://openalex.org/countries/NO',
#    'key_display_name': 'Norway',
#    'count': 125},
#   {'key': 'https://openalex.org/countries/GR',
#    'key_display_name': 'Greece',
#    'count': 124},
#   {'key': 'https://openalex.org/countries/PL',
#    'key_display_name': 'Poland',
#    'count': 124},
#   {'key': 'https://openalex.org/countries/RU',
#    'key_display_name': 'Russian Federation',
#    'count': 112},
#   {'key': 'https://openalex.org/countries/AT',
#    'key_display_name': 'Austria',
#    'count': 105},
#   {'key': 'https://openalex.org/countries/DK',
#    'key_display_name': 'Denmark',
#    'count': 102},
#   {'key': 'https://openalex.org/countries/BE',
#    'key_display_name': 'Belgium',
#    'count': 100},
#   {'key': 'https://openalex.org/countries/HK',
#    'key_display_name': 'Hong Kong',
#    'count': 100},
#   {'key': 'https://openalex.org/countries/NZ',
#    'key_display_name': 'New Zealand',
#    'count': 99},
#   {'key': 'https://openalex.org/countries/MX',
#    'key_display_name': 'Mexico',
#    'count': 97},
#   {'key': 'https://openalex.org/countries/RO',
#    'key_display_name': 'Romania',
#    'count': 96},
#   {'key': 'https://openalex.org/countries/PK',
#    'key_display_name': 'Pakistan',
#    'count': 92},
#   {'key': 'https://openalex.org/countries/SA',
#    'key_display_name': 'Saudi Arabia',
#    'count': 88},
#   {'key': 'https://openalex.org/countries/TW',
#    'key_display_name': 'Taiwan, Province of China',
#    'count': 88},
#   {'key': 'https://openalex.org/countries/FI',
#    'key_display_name': 'Finland',
#    'count': 81},
#   {'key': 'https://openalex.org/countries/SG',
#    'key_display_name': 'Singapore',
#    'count': 79},
#   {'key': 'https://openalex.org/countries/EG',
#    'key_display_name': 'Egypt',
#    'count': 77},
#   {'key': 'https://openalex.org/countries/BD',
#    'key_display_name': 'Bangladesh',
#    'count': 73},
#   {'key': 'https://openalex.org/countries/IE',
#    'key_display_name': 'Ireland',
#    'count': 73},
#   {'key': 'https://openalex.org/countries/NG',
#    'key_display_name': 'Nigeria',
#    'count': 66},
#   {'key': 'https://openalex.org/countries/PH',
#    'key_display_name': 'Philippines',
#    'count': 66},
#   {'key': 'https://openalex.org/countries/AE',
#    'key_display_name': 'United Arab Emirates',
#    'count': 55},
#   {'key': 'https://openalex.org/countries/TH',
#    'key_display_name': 'Thailand',
#    'count': 54},
#   {'key': 'https://openalex.org/countries/CL',
#    'key_display_name': 'Chile',
#    'count': 51},
#   {'key': 'https://openalex.org/countries/IL',
#    'key_display_name': 'Israel',
#    'count': 50},
#   {'key': 'https://openalex.org/countries/CO',
#    'key_display_name': 'Colombia',
#    'count': 49},
#   {'key': 'https://openalex.org/countries/CZ',
#    'key_display_name': 'Czechia',
#    'count': 49},
#   {'key': 'https://openalex.org/countries/KE',
#    'key_display_name': 'Kenya',
#    'count': 47},
#   {'key': 'https://openalex.org/countries/MA',
#    'key_display_name': 'Morocco',
#    'count': 44},
#   {'key': 'https://openalex.org/countries/UA',
#    'key_display_name': 'Ukraine',
#    'count': 43},
#   {'key': 'https://openalex.org/countries/HU',
#    'key_display_name': 'Hungary',
#    'count': 41},
#   {'key': 'https://openalex.org/countries/LK',
#    'key_display_name': 'Sri Lanka',
#    'count': 33},
#   {'key': 'https://openalex.org/countries/HR',
#    'key_display_name': 'Croatia',
#    'count': 32},
#   {'key': 'https://openalex.org/countries/GH',
#    'key_display_name': 'Ghana',
#    'count': 31},
#   {'key': 'https://openalex.org/countries/EC',
#    'key_display_name': 'Ecuador',
#    'count': 27},
#   {'key': 'https://openalex.org/countries/ET',
#    'key_display_name': 'Ethiopia',
#    'count': 27},
#   {'key': 'https://openalex.org/countries/CY',
#    'key_display_name': 'Cyprus',
#    'count': 26},
#   {'key': 'https://openalex.org/countries/QA',
#    'key_display_name': 'Qatar',
#    'count': 25},
#   {'key': 'https://openalex.org/countries/SI',
#    'key_display_name': 'Slovenia',
#    'count': 25},
#   {'key': 'https://openalex.org/countries/VN',
#    'key_display_name': 'Viet Nam',
#    'count': 25},
#   {'key': 'https://openalex.org/countries/PE',
#    'key_display_name': 'Peru',
#    'count': 24},
#   {'key': 'https://openalex.org/countries/MO',
#    'key_display_name': 'Macao',
#    'count': 23},
#   {'key': 'https://openalex.org/countries/RS',
#    'key_display_name': 'Serbia',
#    'count': 23},
#   {'key': 'https://openalex.org/countries/LT',
#    'key_display_name': 'Lithuania',
#    'count': 21},
#   {'key': 'https://openalex.org/countries/TN',
#    'key_display_name': 'Tunisia',
#    'count': 21},
#   {'key': 'https://openalex.org/countries/JO',
#    'key_display_name': 'Jordan',
#    'count': 20},
#   {'key': 'https://openalex.org/countries/LB',
#    'key_display_name': 'Lebanon',
#    'count': 20},
#   {'key': 'https://openalex.org/countries/IQ',
#    'key_display_name': 'Iraq',
#    'count': 19},
#   {'key': 'https://openalex.org/countries/ZW',
#    'key_display_name': 'Zimbabwe',
#    'count': 19},
#   {'key': 'https://openalex.org/countries/EE',
#    'key_display_name': 'Estonia',
#    'count': 18},
#   {'key': 'https://openalex.org/countries/SK',
#    'key_display_name': 'Slovakia',
#    'count': 18},
#   {'key': 'https://openalex.org/countries/BG',
#    'key_display_name': 'Bulgaria',
#    'count': 17},
#   {'key': 'https://openalex.org/countries/AR',
#    'key_display_name': 'Argentina',
#    'count': 15},
#   {'key': 'https://openalex.org/countries/LV',
#    'key_display_name': 'Latvia',
#    'count': 15},
#   {'key': 'https://openalex.org/countries/NP',
#    'key_display_name': 'Nepal',
#    'count': 15},
#   {'key': 'https://openalex.org/countries/LU',
#    'key_display_name': 'Luxembourg',
#    'count': 14},
#   {'key': 'https://openalex.org/countries/UG',
#    'key_display_name': 'Uganda',
#    'count': 14},
#   {'key': 'https://openalex.org/countries/SN',
#    'key_display_name': 'Senegal',
#    'count': 13},
#   {'key': 'https://openalex.org/countries/OM',
#    'key_display_name': 'Oman',
#    'count': 12},
#   {'key': 'https://openalex.org/countries/FJ',
#    'key_display_name': 'Fiji',
#    'count': 10},
#   {'key': 'https://openalex.org/countries/CM',
#    'key_display_name': 'Cameroon',
#    'count': 8},
#   {'key': 'https://openalex.org/countries/IS',
#    'key_display_name': 'Iceland',
#    'count': 8},
#   {'key': 'https://openalex.org/countries/CI',
#    'key_display_name': "Côte d'Ivoire",
#    'count': 7},
#   {'key': 'https://openalex.org/countries/DZ',
#    'key_display_name': 'Algeria',
#    'count': 7},
#   {'key': 'https://openalex.org/countries/KW',
#    'key_display_name': 'Kuwait',
#    'count': 7},
#   {'key': 'https://openalex.org/countries/KZ',
#    'key_display_name': 'Kazakhstan',
#    'count': 7},
#   {'key': 'https://openalex.org/countries/MT',
#    'key_display_name': 'Malta',
#    'count': 7},
#   {'key': 'https://openalex.org/countries/MW',
#    'key_display_name': 'Malawi',
#    'count': 7},
#   {'key': 'https://openalex.org/countries/YE',
#    'key_display_name': 'Yemen',
#    'count': 7},
#   {'key': 'https://openalex.org/countries/AZ',
#    'key_display_name': 'Azerbaijan',
#    'count': 6},
#   {'key': 'https://openalex.org/countries/BA',
#    'key_display_name': 'Bosnia and Herzegovina',
#    'count': 6},
#   {'key': 'https://openalex.org/countries/PS',
#    'key_display_name': 'Palestine, State of',
#    'count': 6},
#   {'key': 'https://openalex.org/countries/SS',
#    'key_display_name': 'South Sudan',
#    'count': 6},
#   {'key': 'https://openalex.org/countries/TT',
#    'key_display_name': 'Trinidad and Tobago',
#    'count': 6},
#   {'key': 'https://openalex.org/countries/TZ',
#    'key_display_name': 'Tanzania, United Republic of',
#    'count': 6},
#   {'key': 'https://openalex.org/countries/AL',
#    'key_display_name': 'Albania',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/CU',
#    'key_display_name': 'Cuba',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/MG',
#    'key_display_name': 'Madagascar',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/MK',
#    'key_display_name': 'North Macedonia',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/MM',
#    'key_display_name': 'Myanmar',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/PA',
#    'key_display_name': 'Panama',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/PR',
#    'key_display_name': 'Puerto Rico',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/SM',
#    'key_display_name': 'San Marino',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/UY',
#    'key_display_name': 'Uruguay',
#    'count': 5},
#   {'key': 'https://openalex.org/countries/AM',
#    'key_display_name': 'Armenia',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/BB',
#    'key_display_name': 'Barbados',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/BJ',
#    'key_display_name': 'Benin',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/BN',
#    'key_display_name': 'Brunei Darussalam',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/CD',
#    'key_display_name': 'Congo, Democratic Republic of the',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/CR',
#    'key_display_name': 'Costa Rica',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/JM',
#    'key_display_name': 'Jamaica',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/NA',
#    'key_display_name': 'Namibia',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/RW',
#    'key_display_name': 'Rwanda',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/UZ',
#    'key_display_name': 'Uzbekistan',
#    'count': 4},
#   {'key': 'https://openalex.org/countries/BH',
#    'key_display_name': 'Bahrain',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/BY',
#    'key_display_name': 'Belarus',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/CG',
#    'key_display_name': 'Congo',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/KH',
#    'key_display_name': 'Cambodia',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/MC',
#    'key_display_name': 'Monaco',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/MD',
#    'key_display_name': 'Moldova, Republic of',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/ME',
#    'key_display_name': 'Montenegro',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/PG',
#    'key_display_name': 'Papua New Guinea',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/SD',
#    'key_display_name': 'Sudan',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/VE',
#    'key_display_name': 'Venezuela, Bolivarian Republic of',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/VU',
#    'key_display_name': 'Vanuatu',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/ZM',
#    'key_display_name': 'Zambia',
#    'count': 3},
#   {'key': 'https://openalex.org/countries/AF',
#    'key_display_name': 'Afghanistan',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/BT',
#    'key_display_name': 'Bhutan',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/BW',
#    'key_display_name': 'Botswana',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/FM',
#    'key_display_name': 'Micronesia, Federated States of',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/GY',
#    'key_display_name': 'Guyana',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/KI',
#    'key_display_name': 'Kiribati',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/MN',
#    'key_display_name': 'Mongolia',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/NE',
#    'key_display_name': 'Niger',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/PF',
#    'key_display_name': 'French Polynesia',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/SZ',
#    'key_display_name': 'Eswatini',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/TG',
#    'key_display_name': 'Togo',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/TO',
#    'key_display_name': 'Tonga',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/WS',
#    'key_display_name': 'Samoa',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/XK',
#    'key_display_name': 'Kosovo',
#    'count': 2},
#   {'key': 'https://openalex.org/countries/BF',
#    'key_display_name': 'Burkina Faso',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/BI',
#    'key_display_name': 'Burundi',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/BO',
#    'key_display_name': 'Bolivia, Plurinational State of',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/DO',
#    'key_display_name': 'Dominican Republic',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/GA',
#    'key_display_name': 'Gabon',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/GE',
#    'key_display_name': 'Georgia',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/GF',
#    'key_display_name': 'French Guiana',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/GN',
#    'key_display_name': 'Guinea',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/HN',
#    'key_display_name': 'Honduras',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/KG',
#    'key_display_name': 'Kyrgyzstan',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/KY',
#    'key_display_name': 'Cayman Islands',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/LY',
#    'key_display_name': 'Libya',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/ML',
#    'key_display_name': 'Mali',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/MV',
#    'key_display_name': 'Maldives',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/NC',
#    'key_display_name': 'New Caledonia',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/RE',
#    'key_display_name': 'Réunion',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/SB',
#    'key_display_name': 'Solomon Islands',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/SC',
#    'key_display_name': 'Seychelles',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/SY',
#    'key_display_name': 'Syrian Arab Republic',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/TD',
#    'key_display_name': 'Chad',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/TJ',
#    'key_display_name': 'Tajikistan',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/TL',
#    'key_display_name': 'Timor-Leste',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/TV',
#    'key_display_name': 'Tuvalu',
#    'count': 1},
#   {'key': 'https://openalex.org/countries/VA',
#    'key_display_name': 'Holy See',
#    'count': 1}]}

# %%
dict_countries=[]

for year in range(2013,2024,1):
    url=f"https://api.openalex.org/works?filter=has_doi:true,publication_year:{year},keyword.search:({climat_keywords_str2}),title_and_abstract.search:({climat_topics_OR_str2})&group-by=institutions.country_code"
    response = requests.get(url)
    data = response.json()
    for i in range(0,30,1):
        dict_countries.append({"year":str(year),'country':data['group_by'][i]['key'].replace('https://openalex.org/countries/',''),'count':data['group_by'][i]['count'],'total':data['meta']['count'], 'rank': i+1})

# %%
df=pd.DataFrame(dict_countries)
df['percentage']=df.apply(lambda row: round(row['count']*100/row['total'],1),axis=1)

# %% [markdown]
# with Highcharts

# %%
# pip install virtualenv
# virtualenv -p python3.10 myenv
# myenv\Scripts\activate
# pip install highcharts_core

# %%
from highcharts_core.chart import Chart
from highcharts_core.options import HighchartsOptions
from highcharts_core.options.plot_options import PlotOptions
from highcharts_core.options.axes.x_axis import XAxis
from highcharts_core.options.axes.y_axis import YAxis,YAxisTitle
from highcharts_core.options.axes.accessibility import AxisAccessibility
from highcharts_core.options.axes.title import AxisTitle
from highcharts_core.options.title import Title
from highcharts_core.options.subtitle import Subtitle
from highcharts_core.options.legend import Legend
from highcharts_core.options.plot_options.series import SeriesOptions
from highcharts_core.options.series.area import LineSeries
from highcharts_core.options.series.labels import SeriesLabel
from highcharts_core.options.responsive import Responsive, ResponsiveRules, Condition
from highcharts_core.constants import EnforcedNull
from highcharts_core.options.credits import Credits

# %%
chart_options = HighchartsOptions(
    chart={
        'width': 800,  
        'height': 600  
    },
    title = Title(text = 'Part of publications in OpenAlex for 10 countries by year', #Part of publications in OpenAlex for 10 countries by year
                  align = 'left',                                                    #Rank for 10 countries by year in OpenAlex publications
                  style={'fontSize': '40px'}),                                                 
    subtitle = Subtitle(text = 'Source: <a href="https://irecusa.org/programs/solar-jobs-census/" target="_blank">OpenAlex</a>',
                        align = 'left'),
    y_axis = YAxis(title = YAxisTitle(text = 'Part', style={'fontSize': '20px'}), style={'fontSize': '30px'}, min=1, labels={'style': {'fontSize': '20px'}}), #reversed=True
    x_axis = XAxis(title = AxisTitle(text = 'Year', style={'fontSize': '20px'}),
                   labels={'style': {'fontSize': '20px'}},
        accessibility = AxisAccessibility(range_description = 'Range: 2013 to 2023')),
    legend = Legend(layout = 'vertical',
                    align = 'right',
                    vertical_align = 'middle'),
    plot_options = PlotOptions(series = SeriesOptions(point_start = 2013,
                                                      label = SeriesLabel(connector_allowed = False,
                                                                          style={'fontSize': '20px'}))),
    credits = Credits(enabled=False),
    exporting={
        'enabled': False  
    }
)

# %%
override_options = HighchartsOptions(legend = Legend(layout = 'horizontal',
                                                     align = 'center',
                                                     vertical_align = 'bottom'))
responsive_config = Responsive(
    rules = [
        ResponsiveRules(chart_options = override_options,
                        condition = Condition(max_width = 500))
    ]
)
chart_options.responsive = responsive_config

# %%
','.join(list(df[df.year=='2022'].country))
# Out:
# 'US,CN,GB,ID,IT,DE,AU,IN,CA,NL,IR,FR,ES,JP,BR,MY,SE,ZA,TR,PT,KR,CH,NO,GR,PL,RU,AT,DK,BE,HK'

# %%
df[df.year=='2022']
# Out:
#      year country  count  total  rank  percentage
# 270  2022      US   2223  13405     1        16.6
# 271  2022      CN   1212  13405     2         9.0
# 272  2022      GB    975  13405     3         7.3
# 273  2022      ID    594  13405     4         4.4
# 274  2022      IT    520  13405     5         3.9
# 275  2022      DE    497  13405     6         3.7
# 276  2022      AU    463  13405     7         3.5
# 277  2022      IN    445  13405     8         3.3
# 278  2022      CA    407  13405     9         3.0
# 279  2022      NL    310  13405    10         2.3
# 280  2022      IR    307  13405    11         2.3
# 281  2022      FR    291  13405    12         2.2
# 282  2022      ES    270  13405    13         2.0
# 283  2022      JP    247  13405    14         1.8
# 284  2022      BR    200  13405    15         1.5
# 285  2022      MY    167  13405    16         1.2
# 286  2022      SE    164  13405    17         1.2
# 287  2022      ZA    164  13405    18         1.2
# 288  2022      TR    148  13405    19         1.1
# 289  2022      PT    134  13405    20         1.0
# 290  2022      KR    132  13405    21         1.0
# 291  2022      CH    131  13405    22         1.0
# 292  2022      NO    125  13405    23         0.9
# 293  2022      GR    124  13405    24         0.9
# 294  2022      PL    124  13405    25         0.9
# 295  2022      RU    112  13405    26         0.8
# 296  2022      AT    105  13405    27         0.8
# 297  2022      DK    102  13405    28         0.8
# 298  2022      BE    100  13405    29         0.7
# 299  2022      HK    100  13405    30         0.7

# %%
series1 = LineSeries(name = 'US',
                     data = list(df[df.country=='US']['percentage']))
series2 = LineSeries(name = 'CN',
                     data = list(df[df.country=='CN']['percentage']),
                    color = 'green')
series3 = LineSeries(name = 'IN',
                     data = list(df[df.country=='IN']['percentage']),
                     color = 'red')
series4 = LineSeries(name = 'GB',
                     data = list(df[df.country=='GB']['percentage']),
                     color= 'purple')
series5 = LineSeries(name = 'ID',
                     data = list(df[df.country=='ID']['percentage']),
                     color = 'blue')
series6 = LineSeries(name = 'DE',
                     data = list(df[df.country=='DE']['percentage']),
                     color = 'orange')
series9 = LineSeries(name = 'IT',
                     data = list(df[df.country=='IT']['percentage']),
                     color = 'green')
series7 = LineSeries(name = 'AU',
                     data = list(df[df.country=='AU']['percentage']),
                     color = 'grey')
series8 = LineSeries(name = 'ES',
                     data = list(df[df.country=='ES']['percentage']),
                     color = 'brown')
series9 = LineSeries(name = 'CA',
                     data = list(df[df.country=='CA']['percentage']),
                     color = 'green')
series10 = LineSeries(name = 'FR',
                     data = list(df[df.country=='FR']['percentage']),
                     color = 'yellow')

chart_options.add_series(series1, series2, series3, series4, series5, series6, series9, series7,series8,series9,series10)

# %%
chart = Chart.from_options(chart_options)
chart.display()
# Out:
# <div id="highcharts_target_div_WQF4NT" style="width:100%; height:600;"></div>

# %%
chart_options = HighchartsOptions(
    chart={
        'width': 800,  
        'height': 600  
    },
    title = Title(text = 'Rank for 10 countries by year in OpenAlex publications', #Part of publications in OpenAlex for 10 countries by year
                  align = 'left',                                                    #Rank for 10 countries by year in OpenAlex publications
                  style={'fontSize': '40px'}),                                                 
    subtitle = Subtitle(text = 'Source: <a href="https://irecusa.org/programs/solar-jobs-census/" target="_blank">OpenAlex</a>',
                        align = 'left'),
    y_axis = YAxis(title = YAxisTitle(text = 'Rank', style={'fontSize': '20px'}), reversed=True, style={'fontSize': '30px'}, min=1, labels={'style': {'fontSize': '20px'}}), #reversed=True
    x_axis = XAxis(title = AxisTitle(text = 'Year', style={'fontSize': '20px'}),
                   labels={'style': {'fontSize': '20px'}},
        accessibility = AxisAccessibility(range_description = 'Range: 2013 to 2023')),
    legend = Legend(layout = 'vertical',
                    align = 'right',
                    vertical_align = 'middle'),
    plot_options = PlotOptions(series = SeriesOptions(point_start = 2013,
                                                      label = SeriesLabel(connector_allowed = False,
                                                                          style={'fontSize': '20px'}))),
    credits = Credits(enabled=False),
    exporting={
        'enabled': False  
    }
)
override_options = HighchartsOptions(legend = Legend(layout = 'horizontal',
                                                     align = 'center',
                                                     vertical_align = 'bottom'))
responsive_config = Responsive(
    rules = [
        ResponsiveRules(chart_options = override_options,
                        condition = Condition(max_width = 500))
    ]
)
chart_options.responsive = responsive_config

series1 = LineSeries(name = 'US',
                     data = list(df[df.country=='US']['rank']))
series2 = LineSeries(name = 'CN',
                     data = list(df[df.country=='CN']['rank']),
                    color = 'green')
series3 = LineSeries(name = 'IN',
                     data = list(df[df.country=='IN']['rank']),
                     color = 'red')
series4 = LineSeries(name = 'GB',
                     data = list(df[df.country=='GB']['rank']),
                     color= 'purple')
series5 = LineSeries(name = 'ID',
                     data = list(df[df.country=='ID']['rank']),
                     color = 'blue')
series6 = LineSeries(name = 'DE',
                     data = list(df[df.country=='DE']['rank']),
                     color = 'orange')
series9 = LineSeries(name = 'IT',
                     data = list(df[df.country=='IT']['rank']),
                     color = 'green')
series7 = LineSeries(name = 'AU',
                     data = list(df[df.country=='AU']['rank']),
                     color = 'grey')
series8 = LineSeries(name = 'ES',
                     data = list(df[df.country=='ES']['rank']),
                     color = 'brown')
series9 = LineSeries(name = 'CA',
                     data = list(df[df.country=='CA']['rank']),
                     color = 'green')
series10 = LineSeries(name = 'FR',
                     data = list(df[df.country=='FR']['rank']),
                     color = 'yellow')

chart_options.add_series(series1, series2, series3, series4, series5, series6, series9, series7,series8,series9,series10)

chart = Chart.from_options(chart_options)
chart.display()
# Out:
# <div id="highcharts_target_div_I08X82" style="width:100%; height:600;"></div>

# %%
url=f"https://api.openalex.org/works?filter=has_doi:true,publication_year:{2019},keyword.search:({climat_keywords_str2}),title_and_abstract.search:({climat_topics_OR_str2})&group-by=topics.field.id"
response = requests.get(url)
data = response.json()

# %%
dict_countries2=[]
max=0

for year in range(2019,2024,1):
    url=f"https://api.openalex.org/works?filter=has_doi:true,publication_year:{year},keyword.search:({climat_keywords_str2}),title_and_abstract.search:({climat_topics_OR_str2}),institutions.country_code:FR&group-by=topics.field.id"
    response = requests.get(url)
    data = response.json()
    for i in range(len(data['group_by'])):
        dict_countries2.append({"year":str(year),'field':data['group_by'][i]['key_display_name'],'count':data['group_by'][i]['count'],'total':data['meta']['count'], 'rank': i+1})

# %%
df=pd.DataFrame(dict_countries2)
df['percentage']=df.apply(lambda row: round(row['count']*100/row['total'],1),axis=1)

# %%
df[df.year=='2021']
# Out:
#     year                                         field  count  total  rank  \
# 52  2021                                   Engineering     77    293     1
# 53  2021                         Environmental Science     76    293     2
# 54  2021           Business, Management and Accounting     58    293     3
# 55  2021                               Social Sciences     52    293     4
# 56  2021          Agricultural and Biological Sciences     49    293     5
# 57  2021                              Computer Science     33    293     6
# 58  2021           Economics, Econometrics and Finance     30    293     7
# 59  2021                            Health Professions     29    293     8
# 60  2021                         Physics and Astronomy     26    293     9
# 61  2021                                      Medicine     18    293    10
# 62  2021                             Decision Sciences     17    293    11
# 63  2021                  Earth and Planetary Sciences     17    293    12
# 64  2021                                    Psychology     14    293    13
# 65  2021  Biochemistry, Genetics and Molecular Biology     13    293    14
# 66  2021                                  Neuroscience      5    293    15
# 67  2021                                    Veterinary      5    293    16
# 68  2021                           Arts and Humanities      4    293    17
# 69  2021                                        Energy      3    293    18
# 70  2021                                   Mathematics      3    293    19
# 71  2021                             Materials Science      2    293    20
# 72  2021                                     Chemistry      0    293    21
# 73  2021                   Immunology and Microbiology      0    293    22
# 74  2021                                       Nursing      0    293    23
# 75  2021    Pharmacology, Toxicology and Pharmaceutics      0    293    24
# 76  2021                          Chemical Engineering      0    293    25
# 77  2021                                     Dentistry      0    293    26
#
#     percentage
# 52        26.3
# 53        25.9
# 54        19.8
# 55        17.7
# 56        16.7
# 57        11.3
# 58        10.2
# 59         9.9
# 60         8.9
# 61         6.1
# 62         5.8
# 63         5.8
# 64         4.8
# 65         4.4
# 66         1.7
# 67         1.7
# 68         1.4
# 69         1.0
# 70         1.0
# 71         0.7
# 72         0.0
# 73         0.0
# 74         0.0
# 75         0.0
# 76         0.0
# 77         0.0

# %%
categories = list(df[df.year == '2022'].field)[:20]
part_2022 = [float(df[(df.year == '2022') & (df.field == i)].percentage) for i in categories]
part_2019 = [float(df[(df.year == '2019') & (df.field == i)].percentage) for i in categories]

options_as_str = f"""
{{
    chart: {{
        type: 'column'
    }},
    title: {{
        text: 'Part of publication about durability in 2022'
    }},
    subtitle: {{
        text: 'Source: OpenAlex.com'
    }},
    xAxis: {{
        categories: {categories},
        crosshair: true
    }},
    yAxis: {{
        min: 0,
        title: {{
            text: 'part'
        }}
    }},
    tooltip: {{
        headerFormat: '<span style="font-size:10px">{{point.key}}</span><table>',
        pointFormat: '<tr><td style="color:{{series.color}};padding:0">{{series.name}}: </td><td style="padding:0"><b>{{point.y:.1f}} %</b></td></tr>',
        footerFormat: '</table>',
        shared: true,
        useHTML: true
    }},
    plotOptions: {{
        column: {{
            pointPadding: 0.2,
            borderWidth: 0
        }}
    }},
    series: [{{
        name: '2022',
        data: {part_2022}
    }}]
}}
"""

options = HighchartsOptions.from_js_literal(options_as_str)
# Out:
# C:\Users\haallat\AppData\Local\Temp\ipykernel_21512\1511536401.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   part_2022 = [float(df[(df.year == '2022') & (df.field == i)].percentage) for i in categories]
# C:\Users\haallat\AppData\Local\Temp\ipykernel_21512\1511536401.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   part_2019 = [float(df[(df.year == '2019') & (df.field == i)].percentage) for i in categories]

# %%
chart = Chart.from_options(options)
chart.display()
# Out:
# <div id="highcharts_target_div_XHGQL6" style="width:100%; height:400;"></div>

# %%
df_tot=df[['year','total']].drop_duplicates()
df_tot
# Out:
#      year  total
# 0    2019    150
# 26   2020    211
# 52   2021    293
# 78   2022    291
# 104  2023    320

# %%
chart_options = HighchartsOptions(
    chart={
        'width': 800,  
        'height': 600  
    },
    title = Title(text = 'Number of publications in OpenAlex about durability since 2019', 
                  align = 'left',                                                    
                  style={'fontSize': '40px'}),                                                 
    subtitle = Subtitle(text = 'Source: <a href="https://irecusa.org/programs/solar-jobs-census/" target="_blank">OpenAlex</a>',
                        align = 'left'),
    y_axis = YAxis(title = YAxisTitle(text = 'Number', style={'fontSize': '20px'}), style={'fontSize': '30px'}, min=1, labels={'style': {'fontSize': '20px'}}), #reversed=True
    x_axis = XAxis(title = AxisTitle(text = 'Year', style={'fontSize': '20px'}),
                   labels={'style': {'fontSize': '20px'}},
        accessibility = AxisAccessibility(range_description = 'Range: 2019 to 2023')),
    legend = Legend(layout = 'vertical',
                    align = 'right',
                    vertical_align = 'middle'),
    plot_options = PlotOptions(series = SeriesOptions(point_start = 2019,
                                                      label = SeriesLabel(connector_allowed = False,
                                                                          style={'fontSize': '20px'}))),
    credits = Credits(enabled=False),
    exporting={
        'enabled': False  
    }
)
override_options = HighchartsOptions(legend = Legend(layout = 'horizontal',
                                                     align = 'center',
                                                     vertical_align = 'bottom'))
responsive_config = Responsive(
    rules = [
        ResponsiveRules(chart_options = override_options,
                        condition = Condition(max_width = 500))
    ]
)
chart_options.responsive = responsive_config

series1 = LineSeries(name = 'all',
                     data = list(df_tot['total']))
series2 = LineSeries(name = 'Environmental science',
                     data = list(df[df.field=='Environmental Science']['count']),
                    color = 'green')

chart_options.add_series(series1, series2)

chart = Chart.from_options(chart_options)
chart.display()
# Out:
# <div id="highcharts_target_div_VFS7F2" style="width:100%; height:600;"></div>

# %%
dict_countriestot=[]

for year in range(2013,2024,1):
    url=f"https://api.openalex.org/works?filter=has_doi:true,publication_year:{year}&group-by=institutions.country_code"
    response = requests.get(url)
    data = response.json()
    for i in range(0,30,1):
        dict_countriestot.append({"year":str(year),'country':data['group_by'][i]['key'].replace('https://openalex.org/countries/',''),'count':data['group_by'][i]['count'],'total':data['meta']['count'], 'rank': i+1})

# %%
dftot=pd.DataFrame(dict_countriestot)
dftot['percentagetot']=df.apply(lambda row: round(row['count']*100/row['total'],1),axis=1)

# %%
dftot
# Out:
#      year country   count    total  rank  percentagetot
# 0    2013      US  800210  4926668     1           22.4
# 1    2013      CN  368556  4926668     2           10.4
# 2    2013      GB  226417  4926668     3            4.7
# 3    2013      DE  200083  4926668     4            3.3
# 4    2013      JP  157221  4926668     5            3.2
# ..    ...     ...     ...      ...   ...            ...
# 325  2023      MX   57619  9769832    26            0.8
# 326  2023      BE   55593  9769832    27            0.8
# 327  2023      PT   51709  9769832    28            0.8
# 328  2023      TW   50784  9769832    29            0.8
# 329  2023      UA   50296  9769832    30            0.8
#
# [330 rows x 6 columns]

# %%
dftot[dftot.year=='2019'][['country','percentagetot']]
# Out:
#     country  percentagetot
# 180      US           22.0
# 181      CN            8.2
# 182      GB            5.1
# 183      DE            3.7
# 184      IN            3.6
# 185      ID            3.5
# 186      BR            3.3
# 187      JP            2.3
# 188      FR            2.2
# 189      RU            2.1
# 190      CA            2.1
# 191      IT            1.9
# 192      ES            1.9
# 193      AU            1.7
# 194      KR            1.5
# 195      NL            1.4
# 196      TR            1.2
# 197      IR            1.1
# 198      PL            1.0
# 199      CH            1.0
# 200      SE            0.9
# 201      BE            0.9
# 202      MX            0.8
# 203      UA            0.8
# 204      TW            0.8
# 205      MY            0.8
# 206      EG            0.7
# 207      PT            0.7
# 208      DK            0.7
# 209      AT            0.7

# %%
df_indice=pd.merge(df[df.year=='2019'][['country','percentage']],dftot[dftot.year=='2019'][['country','percentagetot']],on='country')

# %%
df_indice['indice_spe']=df_indice.apply(lambda row: round(row['percentage']/row['percentagetot'],3), axis=1)

# %%
df_indice
# Out:
#    country  percentage  percentagetot  indice_spe
# 0       US        22.0           22.0       1.000
# 1       GB         8.2            5.1       1.608
# 2       CN         5.1            8.2       0.622
# 3       IT         3.7            1.9       1.947
# 4       DE         3.6            3.7       0.973
# 5       AU         3.5            1.7       2.059
# 6       CA         3.3            2.1       1.571
# 7       NL         2.3            1.4       1.643
# 8       ID         2.2            3.5       0.629
# 9       FR         2.1            2.2       0.955
# 10      IR         2.1            1.1       1.909
# 11      ES         1.9            1.9       1.000
# 12      JP         1.9            2.3       0.826
# 13      IN         1.7            3.6       0.472
# 14      BR         1.5            3.3       0.455
# 15      SE         1.4            0.9       1.556
# 16      CH         1.2            1.0       1.200
# 17      RU         1.0            2.1       0.476
# 18      KR         0.9            1.5       0.600
# 19      AT         0.8            0.7       1.143
# 20      BE         0.8            0.9       0.889
# 21      PL         0.8            1.0       0.800
# 22      PT         0.7            0.7       1.000
